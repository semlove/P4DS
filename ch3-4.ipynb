# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

ch31=pd.read_csv("C:/gskim/P4DS/data/ch31.csv") 

# Bring them in dataframe-format
df = pd.DataFrame(ch31, columns=['com', 'satis'])
df.boxplot(column = 'satis', by='com', grid = True)
plt.show()
